# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json("results/results.json")
df
# Out:
#         model_name           dataset_name model_params  train_size  test_size
# 0   Rocket_XGBoost         PhonemeSpectra           {}        4667       2001  \
# 1   Rocket_XGBoost                TiSeLac           {}       81714      17973
# 2   Rocket_XGBoost                TiSeLac           {}       81714      17973
# 3   Rocket_XGBoost                TiSeLac           {}       81714      17973
# 4   Rocket_XGBoost                 NATOPS           {}         180        180
# 5   Rocket_XGBoost                 NATOPS           {}         180        180
# 6   Rocket_XGBoost                 NATOPS           {}         180        180
# 7   Rocket_XGBoost                 NATOPS           {}         180        180
# 8   Rocket_XGBoost          FaceDetection           {}        5890       3524
# 9   Rocket_XGBoost  ArabicWordRecognition           {}         275        300
# 10  Rocket_XGBoost  ArabicWordRecognition           {}         275        300
# ...
